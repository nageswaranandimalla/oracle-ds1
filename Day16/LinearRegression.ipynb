# %%
import numpy as np
#from sklearn.linear_model import LinearRegression
X = np.array([[1000], [1500], [2000], [2500]]) 
y = np.array([200, 250, 300, 350])

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
prediction = model.predict([[2200]])
print(f"Predicted price: ${prediction[0]*1000:.2f}")
# Out:
# Predicted price: $320000.00

# %%
prediction1 = model.predict([[1750]])
print(f"Predicted price: ${prediction1[0]*1000:.2f}")
# Out:
# Predicted price: $275000.00

# %%
prediction2 = model.predict([[3000]])
print(f"Predicted price: ${prediction2[0]*1000:.2f}")
# Out:
# Predicted price: $400000.00

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, model.predict(X), color='red', label='Regression Line')
plt.scatter(1750, prediction, color='green', label=f'Prediction (2200 sqft): ${prediction[0]*1000:.0f}')
plt.xlabel('House Size (sqft)')
plt.ylabel('Price ($1000s)')
plt.title('Linear Regression: House Price Prediction')
plt.legend()
plt.grid(True)
plt.show()

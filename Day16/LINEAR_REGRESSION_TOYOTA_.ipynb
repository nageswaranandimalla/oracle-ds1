# %%
 import warnings
 warnings.filterwarnings('ignore')
 import numpy as np
 import pandas as pd
 import matplotlib.pyplot as plt
 import seaborn as sns
 # Direct download link format
 #file_id = "1Y50KBAzhHu2A-mLVgHsEVERewkqPJd8G"
 #url = f"https://drive.google.com/uc?id={file_id}"
 # Read the CSV file
 url=pd.read_csv('Toyota.csv')
url


 toyotadf = pd.read_csv(url)
 toyotadf.head()
 toyotadf.tail()
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#      Doors  Weight
# 1431     3    1025
# 1432     3    1015
# 1433     3    1015
# 1434     3    1015
# 1435     5    1114

# %%
toyotadf.head()
# Out:
#    Unnamed: 0  Price   Age     KM FuelType  HP  MetColor  Automatic    CC  \
# 0           0  13500  23.0  46986   Diesel  90       1.0          0  2000
# 1           1  13750  23.0  72937   Diesel  90       1.0          0  2000
# 2           2  13950  24.0  41711   Diesel  90       NaN          0  2000
# 3           3  14950  26.0  48000   Diesel  90       0.0          0  2000
# 4           4  13750  30.0  38500   Diesel  90       0.0          0  2000
#
#    Doors  Weight
# 0  three    1165
# 1      3    1165
# 2      3    1165
# 3      3    1165
# 4      3    1170

# %%
toyotadf.tail()
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#      Doors  Weight
# 1431     3    1025
# 1432     3    1015
# 1433     3    1015
# 1434     3    1015
# 1435     5    1114

# %%
toyotadf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1436 non-null   int64
#  1   Price       1436 non-null   int64
#  2   Age         1336 non-null   float64
#  3   KM          1436 non-null   object
#  4   FuelType    1336 non-null   object
#  5   HP          1436 non-null   object
#  6   MetColor    1286 non-null   float64
#  7   Automatic   1436 non-null   int64
#  8   CC          1436 non-null   int64
#  9   Doors       1436 non-null   object
#  10  Weight      1436 non-null   int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 123.5+ KB

# %%
toyotadf['HP'].unique()
# Out:
# array(['90', '????', '192', '110', '97', '71', '116', '98', '69', '86',
#        '72', '107', '73'], dtype=object)

# %%
np.unique(toyotadf['KM'])
# Out:
# array(['1', '10000', '100123', ..., '99865', '99971', '??'], dtype=object)

# %%
toyotadf['Doors'].unique(),toyotadf['Automatic'].unique(),toyotadf['MetColor'].unique()
# Out:
# (array(['three', '3', '5', '4', 'four', 'five', '2'], dtype=object),
#  array([0, 1]),
#  array([ 1., nan,  0.]))

# %%
toyotadf['Automatic'] = toyotadf['Automatic'].astype('object')
toyotadf['MetColor'] = toyotadf['MetColor'].astype('O')

print(toyotadf.Automatic.dtype)
print(toyotadf.MetColor.dtype)
# Out:
# object
# object

# %%
toyotadf= pd.read_csv(url,na_values=['??','????'])

# %%
toyotadf['Automatic'].unique(),toyotadf['MetColor'].unique()
# Out:
# (array([0, 1]), array([ 1., nan,  0.]))

# %%
toyotadf.Doors.replace('five',5,inplace=True)
toyotadf.Doors.replace('four',4,inplace=True)
toyotadf.Doors.replace('three',3,inplace=True)
toyotadf.Doors.replace('5',5,inplace=True)
toyotadf.Doors.replace('3',3,inplace=True)
toyotadf.Doors.replace('4',4,inplace=True)
toyotadf.Doors.replace('2',2,inplace=True)

toyotadf['Doors'].unique()
# Out:
# array([3, 5, 4, 2])

# %%
toyotadf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1436 non-null   int64
#  1   Price       1436 non-null   int64
#  2   Age         1336 non-null   float64
#  3   KM          1421 non-null   float64
#  4   FuelType    1336 non-null   object
#  5   HP          1430 non-null   float64
#  6   MetColor    1286 non-null   float64
#  7   Automatic   1436 non-null   int64
#  8   CC          1436 non-null   int64
#  9   Doors       1436 non-null   int64
#  10  Weight      1436 non-null   int64
# dtypes: float64(4), int64(6), object(1)
# memory usage: 123.5+ KB

# %%
toyotadf.isnull().sum()
# Out:
# Unnamed: 0      0
# Price           0
# Age           100
# KM             15
# FuelType      100
# HP              6
# MetColor      150
# Automatic       0
# CC              0
# Doors           0
# Weight          0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,4))
sns.boxplot(toyotadf)
plt.show()

# %%
toyotadf.describe()
# Out:
#         Unnamed: 0         Price          Age             KM           HP  \
# count  1436.000000   1436.000000  1336.000000    1421.000000  1430.000000
# mean    717.500000  10730.824513    55.672156   68647.239972   101.478322
# std     414.681806   3626.964585    18.589804   37333.023589    14.768255
# min       0.000000   4350.000000     1.000000       1.000000    69.000000
# 25%     358.750000   8450.000000    43.000000   43210.000000    90.000000
# 50%     717.500000   9900.000000    60.000000   63634.000000   110.000000
# 75%    1076.250000  11950.000000    70.000000   87000.000000   110.000000
# max    1435.000000  32500.000000    80.000000  243000.000000   192.000000
#
#           MetColor    Automatic           CC        Doors      Weight
# count  1286.000000  1436.000000  1436.000000  1436.000000  1436.00000
# mean      0.674961     0.055710  1566.827994     4.033426  1072.45961
# std       0.468572     0.229441   187.182436     0.952677    52.64112
# ...

# %%
toyotadf['Age'].mean(),toyotadf['Age'].median(),toyotadf['Age'].mode(),
# Out:
# (np.float64(55.67215568862275),
#  60.0,
#  0    65.0
#  Name: Age, dtype: float64)

# %%
toyotadf['Age'].fillna(toyotadf['Age'].median(), inplace=True)

# %%
toyotadf['Price'].mean(),toyotadf['Price'].median(),toyotadf['Price'].mode(),
# Out:
# (np.float64(10730.824512534818),
#  9900.0,
#  0    8950
#  Name: Price, dtype: int64)

# %%
toyotadf['Price'].fillna(toyotadf['Price'].median(), inplace=True)

# %%
toyotadf['FuelType'].value_counts()
# Out:
# FuelType
# Petrol    1177
# Diesel     144
# CNG         15
# Name: count, dtype: int64

# %%
toyotadf['FuelType'].mode()
# Out:
# 0    Petrol
# Name: FuelType, dtype: object

# %%
toyotadf['FuelType'].fillna(toyotadf['FuelType'].value_counts().index[0], inplace=True)

# %%
toyotadf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1436 non-null   int64
#  1   Price       1436 non-null   int64
#  2   Age         1436 non-null   float64
#  3   KM          1421 non-null   float64
#  4   FuelType    1436 non-null   object
#  5   HP          1430 non-null   float64
#  6   MetColor    1286 non-null   float64
#  7   Automatic   1436 non-null   int64
#  8   CC          1436 non-null   int64
#  9   Doors       1436 non-null   int64
#  10  Weight      1436 non-null   int64
# dtypes: float64(4), int64(6), object(1)
# memory usage: 123.5+ KB

# %%
toyotadf['MetColor'].value_counts()
# Out:
# MetColor
# 1.0    868
# 0.0    418
# Name: count, dtype: int64

# %%
toyotadf['MetColor'].mode()
# Out:
# 0    1.0
# Name: MetColor, dtype: float64

# %%
toyotadf['MetColor'].fillna(toyotadf['MetColor'].mode()[0], inplace=True)

# %%
toyotadf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1436 non-null   int64
#  1   Price       1436 non-null   int64
#  2   Age         1436 non-null   float64
#  3   KM          1421 non-null   float64
#  4   FuelType    1436 non-null   object
#  5   HP          1430 non-null   float64
#  6   MetColor    1436 non-null   float64
#  7   Automatic   1436 non-null   int64
#  8   CC          1436 non-null   int64
#  9   Doors       1436 non-null   int64
#  10  Weight      1436 non-null   int64
# dtypes: float64(4), int64(6), object(1)
# memory usage: 123.5+ KB

# %%
toyotadf.isnull().sum()
# Out:
# Unnamed: 0     0
# Price          0
# Age            0
# KM            15
# FuelType       0
# HP             6
# MetColor       0
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64

# %%
#Outlier Detection Using Box plot
plt.figure(figsize=(16, 5))
plt.subplot(1,2,1)
plt1 = sns.boxplot(toyotadf['Age'])
plt.subplot(1,2,2)
plt2 = sns.distplot(toyotadf['Age'])

# %%
#Outlier Detection Using Box plot
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
plt3 = sns.boxplot(toyotadf['KM'])
plt.subplot(1,2,2)
plt4 = sns.distplot(toyotadf['KM'])

# %%
#Outlier Detection Using Box plot
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
plt5 = sns.boxplot(toyotadf['CC'])
plt.subplot(1,2,2)
plt6 = sns.distplot(toyotadf['CC'])

# %%
#Outlier Detection Using Box plot
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
plt5 = sns.boxplot(toyotadf['Weight'])
plt.subplot(1,2,2)
plt6 = sns.distplot(toyotadf['Weight'])

# %%
toyotadf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1436 non-null   int64
#  1   Price       1436 non-null   int64
#  2   Age         1436 non-null   float64
#  3   KM          1421 non-null   float64
#  4   FuelType    1436 non-null   object
#  5   HP          1430 non-null   float64
#  6   MetColor    1436 non-null   float64
#  7   Automatic   1436 non-null   int64
#  8   CC          1436 non-null   int64
#  9   Doors       1436 non-null   int64
#  10  Weight      1436 non-null   int64
# dtypes: float64(4), int64(6), object(1)
# memory usage: 123.5+ KB

# %%
toyotadf['Automatic'] = toyotadf['Automatic'].astype('float64')

# %%
encoded_df = pd.get_dummies(toyotadf)
print(encoded_df.shape)
print(encoded_df.columns)
print(encoded_df.dtypes)
# Out:
# (1436, 13)
# Index(['Unnamed: 0', 'Price', 'Age', 'KM', 'HP', 'MetColor', 'Automatic', 'CC',
#        'Doors', 'Weight', 'FuelType_CNG', 'FuelType_Diesel',
#        'FuelType_Petrol'],
#       dtype='object')
# Unnamed: 0           int64
# Price                int64
# Age                float64
# KM                 float64
# HP                 float64
# MetColor           float64
# Automatic          float64
# CC                   int64
# Doors                int64
# Weight               int64
# FuelType_CNG          bool
# FuelType_Diesel       bool
# FuelType_Petrol       bool
# dtype: object

# %%
encoded_df.head()
# Out:
#    Unnamed: 0  Price   Age       KM    HP  MetColor  Automatic    CC  Doors  \
# 0           0  13500  23.0  46986.0  90.0       1.0        0.0  2000      3
# 1           1  13750  23.0  72937.0  90.0       1.0        0.0  2000      3
# 2           2  13950  24.0  41711.0  90.0       1.0        0.0  2000      3
# 3           3  14950  26.0  48000.0  90.0       0.0        0.0  2000      3
# 4           4  13750  30.0  38500.0  90.0       0.0        0.0  2000      3
#
#    Weight  FuelType_CNG  FuelType_Diesel  FuelType_Petrol
# 0    1165         False             True            False
# 1    1165         False             True            False
# 2    1165         False             True            False
# 3    1165         False             True            False
# 4    1170         False             True            False

# %%
toyotadf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1436 non-null   int64
#  1   Price       1436 non-null   int64
#  2   Age         1436 non-null   float64
#  3   KM          1421 non-null   float64
#  4   FuelType    1436 non-null   object
#  5   HP          1430 non-null   float64
#  6   MetColor    1436 non-null   float64
#  7   Automatic   1436 non-null   float64
#  8   CC          1436 non-null   int64
#  9   Doors       1436 non-null   int64
#  10  Weight      1436 non-null   int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 123.5+ KB

# %%
toyotadf['FuelType'] = toyotadf['FuelType'].astype('category')
# to use 'cat.codes', data type must be 'category'
toyotadf["FuelType_cat"] = toyotadf["FuelType"].cat.codes
print(toyotadf['FuelType_cat'].value_counts())
print(toyotadf['FuelType'].value_counts())
# Out:
# FuelType_cat
# 2    1277
# 1     144
# 0      15
# Name: count, dtype: int64
# FuelType
# Petrol    1277
# Diesel     144
# CNG         15
# Name: count, dtype: int64

# %%
toyotadf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1436 non-null   int64
#  1   Price         1436 non-null   int64
#  2   Age           1436 non-null   float64
#  3   KM            1421 non-null   float64
#  4   FuelType      1436 non-null   category
#  5   HP            1430 non-null   float64
#  6   MetColor      1436 non-null   float64
#  7   Automatic     1436 non-null   float64
#  8   CC            1436 non-null   int64
#  9   Doors         1436 non-null   int64
#  10  Weight        1436 non-null   int64
#  11  FuelType_cat  1436 non-null   int8
# dtypes: category(1), float64(5), int64(5), int8(1)
# memory usage: 115.2 KB

# %%
# Separating 'features' and 'target' variables
x = encoded_df.drop('Price',axis=1)
y = encoded_df['Age']
print(x.shape)
print(y.shape)
# Out:
# (1436, 12)
# (1436,)

# %%
x=toyotadf.Price.values.reshape(-1,1)
x
# Out:
# array([[13500],
#        [13750],
#        [13950],
#        ...,
#        [ 8500],
#        [ 7250],
#        [ 6950]])

# %%
y=toyotadf.Age.values.reshape(-1,1)
y
# Out:
# array([[23.],
#        [23.],
#        [24.],
#        ...,
#        [60.],
#        [70.],
#        [76.]])

# %%
# Scaling input features
from sklearn.preprocessing import MinMaxScaler

# fit scaler on data
norm = MinMaxScaler().fit(x)

# transform data
x = norm.transform(x)
print(x.min())
print(x.max())
# Out:
# 0.0
# 1.0

# %%
from sklearn.preprocessing import StandardScaler
stdscalar = StandardScaler()
encoded_df = stdscalar.fit_transform(encoded_df)
print(encoded_df.min())
print(encoded_df.max())
# Out:
# nan
# nan

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,shuffle=True)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((1148, 1), (288, 1), (1148, 1), (288, 1))

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_,lm.intercept_

y_pred= lm.intercept_+lm.coef_*x_train
y_pred
# Out:
# array([[63.45663748],
#        [57.95702679],
#        [73.82128841],
#        ...,
#        [67.68710725],
#        [82.49375143],
#        [56.89940935]])

# %%
#Prediction for test dataset
y_pred=lm.predict(x_test)
y_pred
# Out:
# array([[ 50.5537047 ],
#        [ 46.74628191],
#        [ 76.14804678],
#        [ 63.45663748],
#        [ 51.61132214],
#        [ 66.41796632],
#        [ 50.5960094 ],
#        [ 54.99569795],
#        [ 48.43846982],
#        [ 61.12987911],
#        [ 44.20800005],
#        [ 42.30428866],
#        [ 66.41796632],
#        [ 54.99569795],
#        [ 55.20722144],
#        [ 74.13857364],
#        [ 65.36034888],
#        [ 59.22616772],
#        [ 56.89940935],
#        [ 59.86073818],
#        [ 69.59081865],
#        [ 59.22616772],
#        [ 60.30493751],
#        [ 57.11093284],
#        [ 59.03579658],
#        [ 69.76003744],
#        [ 74.0328119 ],
#        [ 54.99569795],
#        [ 56.89940935],
#        [ 59.43769121],
#        [ 54.99569795],
#        [ 64.30273144],
#        [ 71.91757702],
#        [ 68.5332012 ],
#        [ 69.80234213],
#        [ 68.5332012 ],
#        [ 63.45663748],
#        [ 67.68710725],
#        [ 59.43769121],
#        [ 61.3414026 ],
# ...

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
mean_absolute_error(y_test,y_pred),np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# (7.575932222445895, np.float64(9.873844262315949))

# %%
plt.scatter(x,y)
plt.scatter(x_test,y_pred)

# %%
from sklearn.metrics import r2_score
from scipy.stats import pearsonr

# Calculate r (Pearson correlation)
r, _ = pearsonr(y_test.flatten(), y_pred.flatten())  # flatten() ensures 1D arrays
print(f"Pearson r (correlation coefficient): {r}")

# Calculate r² (R-squared)
r_squared = r2_score(y_test, y_pred)
print(f"R-squared (coefficient of determination): {r_squared}")
# Out:
# Pearson r (correlation coefficient): 0.8395929030685703
# R-squared (coefficient of determination): 0.7027605640653727

# %%
def outliersTreatment(df1, attr):
    percentile25 = df1[attr].quantile(0.25)
    percentile75 = df1[attr].quantile(0.75)
    iqr = percentile75 - percentile25
    print(percentile25)
    print(percentile75)
    print(iqr)
    upper_limit = percentile75 + 1.5 * iqr
    lower_limit = percentile25 - 1.5 * iqr
    df1[df1[attr] > upper_limit]
    df1[df1[attr] < lower_limit]
    df1 = df1[(df1[attr] <= upper_limit) & (df1[attr] >= lower_limit)]
    plt.figure(figsize=(16, 5))
    sns.boxplot(df1[attr])
    plt.show()
    global df
    df = df1

# %%
outliersTreatment(toyotadf, 'Price')
outliersTreatment(toyotadf, 'Age')
# Out:
# 8450.0
# 11950.0
# 3500.0
# 44.0
# 68.0
# 24.0

# %%
x=toyotadf.Price.values
print(x)
x=toyotadf.Price.values.reshape(-1,1)
x
# Out:
# [13500 13750 13950 ...  8500  7250  6950]
# array([[13500],
#        [13750],
#        [13950],
#        ...,
#        [ 8500],
#        [ 7250],
#        [ 6950]])

# %%
y=toyotadf.Age.values
print(y)
y=toyotadf.Age.values.reshape(-1,1)
y
# Out:
# [23. 23. 24. ... 60. 70. 76.]
# array([[23.],
#        [23.],
#        [24.],
#        ...,
#        [60.],
#        [70.],
#        [76.]])

# %%
x.shape,y.shape
# Out:
# ((1436, 1), (1436, 1))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,shuffle=True)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((1148, 1), (288, 1), (1148, 1), (288, 1))

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_,lm.intercept_

y_pred= lm.intercept_+lm.coef_*x_train
y_pred
# Out:
# array([[-2.80973148],
#        [59.19721786],
#        [55.89018057],
#        ...,
#        [31.08740083],
#        [67.46481111],
#        [42.66203137]])

# %%
#Prediction for test dataset
y_pred=lm.predict(x_test)
y_pred
# Out:
# array([[ 71.59860773],
#        [ 63.53770432],
#        [ 59.19721786],
#        [ 60.02397719],
#        [ 44.52223985],
#        [ 62.0908755 ],
#        [ 71.59860773],
#        [ 71.59860773],
#        [ 62.0908755 ],
#        [ 59.19721786],
#        [ 55.06342124],
#        [ 48.86272631],
#        [ 65.3979128 ],
#        [ 57.13031955],
#        [ 63.33101449],
#        [ 60.02397719],
#        [ 44.72892968],
#        [ 59.40390769],
#        [ 55.06342124],
#        [ 44.52223985],
#        [ 59.81728736],
#        [ 59.19721786],
#        [ 55.89018057],
#        [ 63.33101449],
#        [ 60.251336  ],
#        [ 44.52223985],
#        [ 69.53170942],
#        [ 53.82328225],
#        [ 69.53170942],
#        [ 57.13031955],
#        [ 65.19122297],
#        [ 64.15777381],
#        [ 57.33700938],
#        [ 61.26411617],
#        [ 33.15429914],
#        [ 67.46481111],
#        [ -2.97508335],
#        [ 59.82142115],
#        [ 63.33101449],
#        [ 67.46481111],
# ...

# %%
y_test,y_pred
# Out:
# (array([[80.],
#         [68.],
#         [48.],
#         [67.],
#         [41.],
#         [67.],
#         [80.],
#         [76.],
#         [68.],
#         [49.],
#         [60.],
#         [42.],
#         [75.],
#         [62.],
#         [61.],
#         [68.],
#         [40.],
#         [66.],
#         [57.],
#         [38.],
#         [77.],
#         [64.],
#         [56.],
#         [69.],
#         [57.],
#         [35.],
#         [65.],
#         [40.],
#         [74.],
#         [65.],
#         [77.],
#         [49.],
#         [68.],
#         [66.],
#         [29.],
#         [74.],
#         [ 8.],
#         [51.],
#         [69.],
#         [76.],
#         [79.],
#         [79.],
#         [57.],
#         [74.],
#         [65.],
#         [60.],
#         [60.],
#         [65.],
#         [56.],
#         [27.],
#         [56.],
#         [68.],
#         [56.],
#         [80.],
#         [68.],
#         [65.],
#         [56.],
#         [75.],
# ...

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
mean_absolute_error(y_test,y_pred),np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# (7.675085890928925, np.float64(9.55508877851159))

# %%
plt.scatter(x_test,y_pred)

# %%
df['KM'].dropna(inplace=True)
df['HP'].dropna(inplace=True)

# %%
from sklearn.metrics import r2_score
from scipy.stats import pearsonr

# Calculate r (Pearson correlation)
r, _ = pearsonr(y_test.flatten(), y_pred.flatten())
print(f"Pearson r (correlation coefficient): {r}")

# Calculate r² (R-squared)
r_squared = r2_score(y_test, y_pred)
print(f"R-squared (coefficient of determination): {r_squared}")
# Out:
# Pearson r (correlation coefficient): 0.8528072634254454
# R-squared (coefficient of determination): 0.7246681596964561

# %%
#POLYNOMIAL REGRESSION
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import PolynomialFeatures
trans = PolynomialFeatures(degree=4)
x = trans.fit_transform(x)
print(x.shape)

from sklearn.model_selection import train_test_split
x_train,x_test, y_train,y_test = train_test_split(x,y,test_size=0.2,shuffle=True)
x_train.shape,y_train.shape, x_test.shape,y_test.shape
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)

y_train_pred=lm.predict(x_train)
print('MAE of Polynomial regressions is .. ',mean_absolute_error(y_train,y_train_pred))

y_test_pred=lm.predict(x_test)
print('MAE of Polynomial regressions is .. ',mean_absolute_error(y_test,y_test_pred))
# Out:
# (1436, 5)
# MAE of Polynomial regressions is ..  6.852925629759698
# MAE of Polynomial regressions is ..  6.719408195280305

# %%
print(x_train[:,1].shape)
# Out:
# (1148,)

# %%
print(y_train_pred.flatten().shape)
# Out:
# (1148,)

# %%
plt.scatter(x[:,1],y)
plt.scatter(x_train[:,1].flatten(),y_train_pred.flatten())

# %%
df=df.dropna()
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Price           0
# Age             0
# KM              0
# FuelType        0
# HP              0
# MetColor        0
# Automatic       0
# CC              0
# Doors           0
# Weight          0
# FuelType_cat    0
# dtype: int64

# %%
x=df[['Age','KM','CC']]
y=df["Price"]
print(y)
# Out:
# 0       13500
# 1       13750
# 2       13950
# 3       14950
# 4       13750
#         ...
# 1429     8950
# 1430     8450
# 1431     7500
# 1433     8500
# 1435     6950
# Name: Price, Length: 1406, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
x_train.shape,y_train.shape, x_test.shape,y_test.shape
# Out:
# ((1124, 3), (1124,), (282, 3), (282,))

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred=lm.predict(x_train)
mean_absolute_error(y_train,y_train_pred)
# Out:
# 1210.3223263012899

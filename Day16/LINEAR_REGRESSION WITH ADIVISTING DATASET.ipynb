# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Correct File ID (Extracted from Your Link)
file_id = "1hPU9aVGKrNR-BDZfQ_x3Rf6K-7HyxWDj"
url = f"https://drive.google.com/uc?id={file_id}"

# Read the CSV File
df = pd.read_csv(url)

# Display First 5 Rows
print(df.head())
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.shape
# Out:
# (200, 4)

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
plt.figure(figsize=(16, 5))
plt.subplot(1,2,1)
plt1 = sns.boxplot(df['TV'])
plt.subplot(1,2,2)
plt2 = sns.distplot(df['TV'])

# %%
plt.figure(figsize=(16, 5))
plt.subplot(1,2,1)
plt1 = sns.boxplot(df['Radio'])
plt.subplot(1,2,2)
plt2 = sns.distplot(df['Radio'])

# %%
plt.figure(figsize=(16, 5))
plt.subplot(1,2,1)
plt1 = sns.boxplot(df['Newspaper'])
plt.subplot(1,2,2)
plt2 = sns.distplot(df['Newspaper'])

# %%
plt.figure(figsize=(16, 5))
plt.subplot(1,2,1)
plt1 = sns.boxplot(df['Sales'])
plt.subplot(1,2,2)
plt2 = sns.distplot(df['Sales'])

# %%
df.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
import pandas as pd
file_id = "1hPU9aVGKrNR-BDZfQ_x3Rf6K-7HyxWDj"
url = f"https://drive.google.com/uc?id={file_id}"
df = pd.read_csv(url)
correlation_with_sales = df.corr()['Sales'].sort_values(ascending=False)

print("Correlation with respect to Sales:")
print(correlation_with_sales)
# Out:
# Correlation with respect to Sales:
# Sales        1.000000
# TV           0.901208
# Radio        0.349631
# Newspaper    0.157960
# Name: Sales, dtype: float64

# %%
plt.figure(figsize = (15, 9))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
dfc=df.corr()
dfc["TV"].sort_values(ascending=False)
# Out:
# TV           1.000000
# Sales        0.901208
# Newspaper    0.056648
# Radio        0.054809
# Name: TV, dtype: float64

# %%
x=df.Sales.values
print(x)
x=df.Sales.values.reshape(-1,1)
x
# Out:
# [22.1 10.4 12.  16.5 17.9  7.2 11.8 13.2  4.8 15.6 12.6 17.4  9.2 13.7
#  19.  22.4 12.5 24.4 11.3 14.6 18.  17.5  5.6 20.5  9.7 17.  15.  20.9
#  18.9 10.5 21.4 11.9 13.2 17.4 11.9 17.8 25.4 14.7 10.1 21.5 16.6 17.1
#  20.7 17.9  8.5 16.1 10.6 23.2 19.8  9.7 16.4 10.7 22.6 21.2 20.2 23.7
#   5.5 13.2 23.8 18.4  8.1 24.2 20.7 14.  16.  11.3 11.  13.4 18.9 22.3
#  18.3 12.4  8.8 11.  17.   8.7  6.9 14.2  5.3 11.  11.8 17.3 11.3 13.6
#  21.7 20.2 12.  16.  12.9 16.7 14.   7.3 19.4 22.2 11.5 16.9 16.7 20.5
#  25.4 17.2 16.7 23.8 19.8 19.7 20.7 15.   7.2 12.   5.3 19.8 18.4 21.8
#  17.1 20.9 14.6 12.6 12.2  9.4 15.9  6.6 15.5  7.  16.6 15.2 19.7 10.6
#   6.6 11.9 24.7  9.7  1.6 17.7  5.7 19.6 10.8 11.6  9.5 20.8  9.6 20.7
#  10.9 19.2 20.1 10.4 12.3 10.3 18.2 25.4 10.9 10.1 16.1 11.6 16.6 16.
#  20.6  3.2 15.3 10.1  7.3 12.9 16.4 13.3 19.9 18.  11.9 16.9  8.  17.2
#  17.1 20.   8.4 17.5  7.6 16.7 16.5 27.  20.2 16.7 16.8 17.6 15.5 17.2
# ...

# %%
y=df.TV.values
print(y)
y=df.TV.values.reshape(-1,1)
y
# Out:
# [230.1  44.5  17.2 151.5 180.8   8.7  57.5 120.2   8.6 199.8  66.1 214.7
#   23.8  97.5 204.1 195.4  67.8 281.4  69.2 147.3 218.4 237.4  13.2 228.3
#   62.3 262.9 142.9 240.1 248.8  70.6 292.9 112.9  97.2 265.6  95.7 290.7
#  266.9  74.7  43.1 228.  202.5 177.  293.6 206.9  25.1 175.1  89.7 239.9
#  227.2  66.9 199.8 100.4 216.4 182.6 262.7 198.9   7.3 136.2 210.8 210.7
#   53.5 261.3 239.3 102.7 131.1  69.   31.5 139.3 237.4 216.8 199.1 109.8
#   26.8 129.4 213.4  16.9  27.5 120.5   5.4 116.   76.4 239.8  75.3  68.4
#  213.5 193.2  76.3 110.7  88.3 109.8 134.3  28.6 217.7 250.9 107.4 163.3
#  197.6 184.9 289.7 135.2 222.4 296.4 280.2 187.9 238.2 137.9  25.   90.4
#   13.1 255.4 225.8 241.7 175.7 209.6  78.2  75.1 139.2  76.4 125.7  19.4
#  141.3  18.8 224.  123.1 229.5  87.2   7.8  80.2 220.3  59.6   0.7 265.2
#    8.4 219.8  36.9  48.3  25.6 273.7  43.  184.9  73.4 193.7 220.5 104.6
#   96.2 140.3 240.1 243.2  38.   44.7 280.7 121.  197.6 171.3 187.8   4.1
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,shuffle=True)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((160, 1), (40, 1), (160, 1), (40, 1))

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_,lm.intercept_

y_pred= lm.intercept_+lm.coef_*x_train
y_pred
# Out:
# array([[130.6413787 ],
#        [152.32133578],
#        [182.67327569],
#        [175.44662333],
#        [ 28.0229152 ],
#        [  7.78828859],
#        [ 65.60150747],
#        [  4.89762764],
#        [230.36918127],
#        [226.03318985],
#        [ 91.61745596],
#        [178.33728428],
#        [100.28943879],
#        [ 67.04683794],
#        [194.23591947],
#        [159.54798814],
#        [254.93979929],
#        [153.76666625],
#        [107.51609115],
#        [145.09468342],
#        [252.04913835],
#        [239.0411641 ],
#        [ 61.26551605],
#        [ 43.92155039],
#        [174.00129286],
#        [ 74.2734903 ],
#        [169.66530145],
#        [152.32133578],
#        [179.78261475],
#        [139.31336154],
#        [ 55.48419416],
#        [ 84.3908036 ],
#        [227.47852032],
#        [201.46257183],
#        [110.4067521 ],
#        [139.31336154],
#        [179.78261475],
#        [119.07873493],
#        [187.00926711],
#        [142.20402248],
# ...

# %%
y_pred=lm.predict(x_test)
y_pred
# Out:
# array([[100.28943879],
#        [168.21997097],
#        [295.40905251],
#        [ 98.84410832],
#        [ 45.36688086],
#        [ 85.83613407],
#        [228.9238508 ],
#        [ 23.68692378],
#        [159.54798814],
#        [119.07873493],
#        [158.10265767],
#        [174.00129286],
#        [108.96142162],
#        [176.89195381],
#        [ 82.94547313],
#        [215.91587655],
#        [101.73476926],
#        [169.66530145],
#        [234.70517268],
#        [224.58785938],
#        [ 38.1402285 ],
#        [243.37715552],
#        [171.11063192],
#        [ 95.95344738],
#        [ 51.14820275],
#        [241.93182504],
#        [ 23.68692378],
#        [ 77.16415124],
#        [176.89195381],
#        [ 68.49216841],
#        [100.28943879],
#        [133.53203965],
#        [188.45459758],
#        [ 68.49216841],
#        [ 94.50811691],
#        [ 54.03886369],
#        [230.36918127],
#        [168.21997097],
#        [ 87.28146455],
# ...

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
mean_absolute_error(y_test,y_pred),np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# (27.97008963907019, np.float64(34.643403954079204))

# %%
plt.scatter(x,y)
plt.scatter(x_test,y_pred)

# %%
def outliersTreatment(df1, attr):
    percentile25 = df1[attr].quantile(0.25)
    percentile75 = df1[attr].quantile(0.75)
    iqr = percentile75 - percentile25
    print(percentile25)
    print(percentile75)
    print(iqr)
    upper_limit = percentile75 + 1.5 * iqr
    lower_limit = percentile25 - 1.5 * iqr
    df1[df1[attr] > upper_limit]
    df1[df1[attr] < lower_limit]
    df1 = df1[(df1[attr] <= upper_limit) & (df1[attr] >= lower_limit)]
    plt.figure(figsize=(16, 5))
    sns.boxplot(df1[attr])
    plt.show()
    global df
    df = df1

# %%
outliersTreatment(df, 'Sales')
outliersTreatment(df, 'TV')
# Out:
# 11.0
# 19.05
# 8.05
# 74.375
# 218.825
# 144.45

# %%
x=df.Sales.values
print(x)
x=df.Sales.values.reshape(-1,1)
x
# Out:
# [22.1 10.4 12.  16.5 17.9  7.2 11.8 13.2  4.8 15.6 12.6 17.4  9.2 13.7
#  19.  22.4 12.5 24.4 11.3 14.6 18.  17.5  5.6 20.5  9.7 17.  15.  20.9
#  18.9 10.5 21.4 11.9 13.2 17.4 11.9 17.8 25.4 14.7 10.1 21.5 16.6 17.1
#  20.7 17.9  8.5 16.1 10.6 23.2 19.8  9.7 16.4 10.7 22.6 21.2 20.2 23.7
#   5.5 13.2 23.8 18.4  8.1 24.2 20.7 14.  16.  11.3 11.  13.4 18.9 22.3
#  18.3 12.4  8.8 11.  17.   8.7  6.9 14.2  5.3 11.  11.8 17.3 11.3 13.6
#  21.7 20.2 12.  16.  12.9 16.7 14.   7.3 19.4 22.2 11.5 16.9 16.7 20.5
#  25.4 17.2 16.7 23.8 19.8 19.7 20.7 15.   7.2 12.   5.3 19.8 18.4 21.8
#  17.1 20.9 14.6 12.6 12.2  9.4 15.9  6.6 15.5  7.  16.6 15.2 19.7 10.6
#   6.6 11.9 24.7  9.7  1.6 17.7  5.7 19.6 10.8 11.6  9.5 20.8  9.6 20.7
#  10.9 19.2 20.1 10.4 12.3 10.3 18.2 25.4 10.9 10.1 16.1 11.6 16.6 16.
#  20.6  3.2 15.3 10.1  7.3 12.9 16.4 13.3 19.9 18.  11.9 16.9  8.  17.2
#  17.1 20.   8.4 17.5  7.6 16.7 16.5 27.  20.2 16.7 16.8 17.6 15.5 17.2
# ...

# %%
y=df.TV.values
print(y)
y=df.TV.values.reshape(-1,1)
y
# Out:
# [230.1  44.5  17.2 151.5 180.8   8.7  57.5 120.2   8.6 199.8  66.1 214.7
#   23.8  97.5 204.1 195.4  67.8 281.4  69.2 147.3 218.4 237.4  13.2 228.3
#   62.3 262.9 142.9 240.1 248.8  70.6 292.9 112.9  97.2 265.6  95.7 290.7
#  266.9  74.7  43.1 228.  202.5 177.  293.6 206.9  25.1 175.1  89.7 239.9
#  227.2  66.9 199.8 100.4 216.4 182.6 262.7 198.9   7.3 136.2 210.8 210.7
#   53.5 261.3 239.3 102.7 131.1  69.   31.5 139.3 237.4 216.8 199.1 109.8
#   26.8 129.4 213.4  16.9  27.5 120.5   5.4 116.   76.4 239.8  75.3  68.4
#  213.5 193.2  76.3 110.7  88.3 109.8 134.3  28.6 217.7 250.9 107.4 163.3
#  197.6 184.9 289.7 135.2 222.4 296.4 280.2 187.9 238.2 137.9  25.   90.4
#   13.1 255.4 225.8 241.7 175.7 209.6  78.2  75.1 139.2  76.4 125.7  19.4
#  141.3  18.8 224.  123.1 229.5  87.2   7.8  80.2 220.3  59.6   0.7 265.2
#    8.4 219.8  36.9  48.3  25.6 273.7  43.  184.9  73.4 193.7 220.5 104.6
#   96.2 140.3 240.1 243.2  38.   44.7 280.7 121.  197.6 171.3 187.8   4.1
# ...

# %%
x.shape,y.shape
# Out:
# ((200, 1), (200, 1))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,shuffle=True)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((160, 1), (40, 1), (160, 1), (40, 1))

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_,lm.intercept_

y_pred= lm.intercept_+lm.coef_*x_train
y_pred
# Out:
# array([[188.12636151],
#        [ 48.86505298],
#        [180.79681895],
#        [114.83093597],
#        [122.16047852],
#        [ 54.72868702],
#        [ 84.04685724],
#        [180.79681895],
#        [ 84.04685724],
#        [ 53.26277851],
#        [217.44453173],
#        [148.54683172],
#        [226.23998279],
#        [154.41046576],
#        [232.10361684],
#        [170.53545938],
#        [227.7058913 ],
#        [273.14905514],
#        [ 91.37639979],
#        [298.06949982],
#        [239.43315939],
#        [101.63775937],
#        [218.91044024],
#        [ 43.00141893],
#        [213.04680619],
#        [ 81.11504022],
#        [133.88774661],
#        [215.97862322],
#        [ 22.47869978],
#        [ 85.51276575],
#        [173.4672764 ],
#        [214.5127147 ],
#        [193.98999555],
#        [ 37.13778489],
#        [195.45590406],
#        [183.72863598],
#        [ 79.6491317 ],
#        [166.13773385],
#        [  9.28552318],
#        [169.06955087],
# ...

# %%
y_pred=lm.predict(x_test)
y_pred
# Out:
# array([[236.50134237],
#        [ 73.78549766],
#        [158.80819129],
#        [230.63770832],
#        [195.45590406],
#        [204.25135513],
#        [170.53545938],
#        [ 63.52413809],
#        [299.53540834],
#        [221.84225726],
#        [119.2286615 ],
#        [ 86.97867426],
#        [229.17179981],
#        [257.02406152],
#        [130.95592959],
#        [160.2740998 ],
#        [174.93318491],
#        [110.43321043],
#        [ 31.27415085],
#        [100.17185086],
#        [114.83093597],
#        [ 78.18322319],
#        [ 91.37639979],
#        [213.04680619],
#        [126.55820405],
#        [ 81.11504022],
#        [ -3.90765341],
#        [139.75138065],
#        [ 94.30821681],
#        [ 82.58094873],
#        [251.16042748],
#        [229.17179981],
#        [177.86500193],
#        [ 67.92186362],
#        [130.95592959],
#        [167.60364236],
#        [249.69451897],
#        [210.11498917],
#        [106.0354849 ],
# ...

# %%
y_test,y_pred
# Out:
# (array([[182.6],
#         [149.8],
#         [125.7],
#         [273.7],
#         [225.8],
#         [204.1],
#         [197.6],
#         [ 76.4],
#         [283.6],
#         [262.7],
#         [ 97.2],
#         [ 31.5],
#         [184.9],
#         [216.4],
#         [134.3],
#         [110.7],
#         [262.9],
#         [ 66.1],
#         [  8.7],
#         [112.9],
#         [131.7],
#         [ 44.5],
#         [ 69. ],
#         [219.8],
#         [ 97.5],
#         [ 89.7],
#         [  8.6],
#         [ 78.2],
#         [107.4],
#         [100.4],
#         [250.9],
#         [239.3],
#         [206.8],
#         [ 62.3],
#         [ 94.2],
#         [222.4],
#         [230.1],
#         [217.7],
#         [ 96.2],
#         [137.9]]),
#  array([[236.50134237],
#         [ 73.78549766],
#         [158.80819129],
#         [230.63770832],
#         [195.45590406],
#         [204.25135513],
#         [170.53545938],
#         [ 63.52413809],
#         [299.53540834],
# ...

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
mean_absolute_error(y_test,y_pred),np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# (27.994043608068086, np.float64(34.869095128750345))

# %%
plt.scatter(x,y)
plt.scatter(x_test,y_pred)

# %%
from sklearn.preprocessing import PolynomialFeatures
trans = PolynomialFeatures(degree=4)
x = trans.fit_transform(x)
x.shape
# Out:
# (200, 5)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train,y_test = train_test_split(x,y,test_size=0.2)
x_train.shape,y_train.shape, x_test.shape,y_test.shape
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y.min(),y.max()
# Out:
# (np.float64(0.7), np.float64(296.4))

# %%
y_test_pred=lm.predict(x_test)
print('MAE of Polynomial regressions is .. ',mean_absolute_error(y_test,y_test_pred))
# Out:
# MAE of Polynomial regressions is ..  29.949953776233787

# %%
print(x_train[:,1].shape)
# Out:
# (160,)

# %%
print(y_test_pred.flatten().shape)
# Out:
# (40,)

# %%
plt.scatter(x[:,1],y)
plt.scatter(x_test[:,1].flatten(),y_test_pred.flatten())

# %%
x=df[['Sales','TV','Radio','Newspaper']]
y=df.TV.values.reshape(-1,1)
x.max(),x.min(),y.max(),y.min()
# Out:
# (Sales         27.0
#  TV           296.4
#  Radio         49.6
#  Newspaper    114.0
#  dtype: float64,
#  Sales        1.6
#  TV           0.7
#  Radio        0.0
#  Newspaper    0.3
#  dtype: float64,
#  np.float64(296.4),
#  np.float64(0.7))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train,y_test = train_test_split(x,y,test_size=0.2)
x_train.shape,y_train.shape, x_test.shape,y_test.shape
# Out:
# ((160, 4), (160, 1), (40, 4), (40, 1))

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lm.predict(x_test)
y_pred
# Out:
# array([[  4.1],
#        [121. ],
#        [210.8],
#        [199.8],
#        [ 76.4],
#        [228. ],
#        [117.2],
#        [ 18.8],
#        [ 80.2],
#        [213.4],
#        [228.3],
#        [ 16.9],
#        [217.7],
#        [280.7],
#        [227.2],
#        [199.8],
#        [230.1],
#        [ 25. ],
#        [112.9],
#        [218.5],
#        [177. ],
#        [ 66.9],
#        [ 69.2],
#        [ 85.7],
#        [171.3],
#        [170.2],
#        [109.8],
#        [ 43.1],
#        [253.8],
#        [ 43. ],
#        [ 56.2],
#        [ 25.1],
#        [205. ],
#        [139.3],
#        [166.8],
#        [  8.6],
#        [273.7],
#        [188.4],
#        [175.1],
#        [248.8]])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
mean_absolute_error(y_test,y_pred),np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# (5.595524044110789e-14, np.float64(6.697006637702803e-14))

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
print("Mean absolute error:",mean_absolute_error(train_y,train_x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-d8e4a50d320f> in <cell line: 0>()
#       1 from sklearn.metrics import mean_absolute_error,mean_squared_error
# ----> 2 print("Mean absolute error:",mean_absolute_error(train_y,train_x))
#
# NameError: name 'train_y' is not defined

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Direct download link format
file_id = "1Y50KBAzhHu2A-mLVgHsEVERewkqPJd8G"
url = f"https://drive.google.com/uc?id={file_id}"

# Read the CSV file
tdf = pd.read_csv(url)

# %%
tdf.head()

# %%
tdf.tail()

# %%
tdf.info()

# %%
tdf['HP'].unique()

# %%
np.unique(tdf['HP'])

# %%
#tdf['HP']=tdf['HP'].astype('float64')

# %%
tdf['HP'].unique()

# %%
tdf.HP.replace('90',90,inplace=True)
tdf.HP.replace('????',80,inplace=True)
tdf.HP.replace('192',192,inplace=True)
tdf.HP.replace('110',110,inplace=True)
tdf.HP.replace('97',97,inplace=True)
tdf.HP.replace('71',71,inplace=True)
tdf.HP.replace('116',116,inplace=True)
tdf.HP.replace('98',98,inplace=True)
tdf.HP.replace('69',69,inplace=True)
tdf.HP.replace('86',86,inplace=True)
tdf.HP.replace('72',72,inplace=True)
tdf.HP.replace('107',107,inplace=True)
tdf.HP.replace('73',73,inplace=True)

# %%
tdf['HP'].unique()

# %%
tdf.describe()

tdf['Age'].mean(),tdf['Age'].median(),tdf['Age'].mode(),

tdf['Age'].fillna(tdf['Age'].median(), inplace=True)

tdf['Price'].mean(),tdf['Price'].median(),tdf['Price'].mode(),

tdf['Price'].fillna(tdf['Price'].median(), inplace=True)

tdf['FuelType'].value_counts()

tdf['FuelType'].mode()

tdf['FuelType'].fillna(tdf['FuelType'].value_counts().index[0], inplace=True)

# %%
tdf.info()

# %%
tdf['MetColor'].value_counts()

tdf['MetColor'].mode()

tdf['MetColor'].fillna(tdf['MetColor'].mode()[0], inplace=True)

tdf.info()

# %%
tdf.isnull().sum()

# %%
#Outlier Detection Using Box plot
plt.figure(figsize=(16, 5))
plt.subplot(1,2,1)
plt1 = sns.boxplot(tdf['Age'])
plt.subplot(1,2,2)
plt2 = sns.distplot(tdf['Age'])

#Outlier Detection Using Box plot
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
plt3 = sns.boxplot(tdf['KM'])
plt.subplot(1,2,2)
plt4 = sns.distplot(tdf['KM'])

#Outlier Detection Using Box plot
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
plt5 = sns.boxplot(tdf['CC'])
plt.subplot(1,2,2)
plt6 = sns.distplot(tdf['CC'])

# %%
tdf['Automatic'] = tdf['Automatic'].astype('float64')

encoded_df = pd.get_dummies(tdf)
print(encoded_df.shape)
print(encoded_df.columns)
print(encoded_df.dtypes)

encoded_df.head()

tdf.info()

# %%
tdf['FuelType'] = tdf['FuelType'].astype('category')
# to use 'cat.codes', data type must be 'category'
tdf["FuelType_cat"] = tdf["FuelType"].cat.codes
print(tdf['FuelType_cat'].value_counts())
print(tdf['FuelType'].value_counts())

tdf.info()

# %%
# Separating 'features' and 'target' variables

# %%
x=tdf.Price.values.reshape(-1,1)
x

y=tdf.Age.values.reshape(-1,1)
y

# %%
# Scaling input features
from sklearn.preprocessing import MinMaxScaler

# fit scaler on data
norm = MinMaxScaler().fit(x)

# transform data
x = norm.transform(x)
print(x.min())
print(x.max())

# %%
x = encoded_df.drop('Price',axis=1)
y = encoded_df['Age']
print(x.shape)
print(y.shape)

# %%
from sklearn.preprocessing import StandardScaler
stdscalar = StandardScaler()
encoded_df = stdscalar.fit_transform(encoded_df)
print(encoded_df.min())
print(encoded_df.max())

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,shuffle=True)
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)

# %%
lm.coef_,lm.intercept_

y_pred= lm.intercept_+lm.coef_*x_train
y_pred

#Prediction for test dataset
y_pred=lm.predict(x_test)
y_pred

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
mean_absolute_error(y_test,y_pred),np.sqrt(mean_squared_error(y_test,y_pred))

# %%
plt.scatter(x,y)
plt.scatter(x_test,y_pred)

# %%
from sklearn.metrics import r2_score
from scipy.stats import pearsonr

# %%
# Calculate r (Pearson correlation)
r, _ = pearsonr(y_test.flatten(), y_pred.flatten())  # flatten() ensures 1D arrays
print(f"Pearson r (correlation coefficient): {r}")

# Calculate r² (R-squared)
r_squared = r2_score(y_test, y_pred)
print(f"R-squared (coefficient of determination): {r_squared}")

# %%
def outliersTreatment(df1, attr):
    percentile25 = df1[attr].quantile(0.25)
    percentile75 = df1[attr].quantile(0.75)
    iqr = percentile75 - percentile25
    print(percentile25)
    print(percentile75)
    print(iqr)
    upper_limit = percentile75 + 1.5 * iqr
    lower_limit = percentile25 - 1.5 * iqr
    df1[df1[attr] > upper_limit]
    df1[df1[attr] < lower_limit]
    df1 = df1[(df1[attr] <= upper_limit) & (df1[attr] >= lower_limit)]
    plt.figure(figsize=(16, 5))
    sns.boxplot(df1[attr])
    plt.show()
    global df
    df = df1

outliersTreatment(tdf, 'Price')
outliersTreatment(tdf, 'Age')

# %%
x=tdf.Price.values
print(x)
x=tdf.Price.values.reshape(-1,1)
x

y=tdf.Age.values
print(y)
y=tdf.Age.values.reshape(-1,1)
y

# %%
x.shape,y.shape

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,shuffle=True)
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)

# %%
lm.coef_,lm.intercept_

y_pred= lm.intercept_+lm.coef_*x_train
y_pred

# %%
#Prediction for test dataset
y_pred=lm.predict(x_test)
y_pred

y_test,y_pred

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
mean_absolute_error(y_test,y_pred),np.sqrt(mean_squared_error(y_test,y_pred))

# %%
plt.scatter(x_test,y_pred)

from sklearn.metrics import r2_score
from scipy.stats import pearsonr

# %%
# Calculate r (Pearson correlation)
r, _ = pearsonr(y_test.flatten(), y_pred.flatten())
print(f"Pearson r (correlation coefficient): {r}")

# Calculate r² (R-squared)
r_squared = r2_score(y_test, y_pred)
print(f"R-squared (coefficient of determination): {r_squared}")

# %%
from sklearn.preprocessing import StandardScaler

# Assuming tdf is your cleaned DataFrame
features = ['Age', 'KM', 'HP', 'CC']

# Optionally add more numeric columns here if needed

# Extract numeric feature data
encoded_df = tdf[features]

# Standardize it
stdscalar = StandardScaler()
encoded_df_scaled = stdscalar.fit_transform(encoded_df)

# Convert back to DataFrame for readability
encoded_df_scaled = pd.DataFrame(encoded_df_scaled, columns=features)

# Print min/max values
print("Min value after scaling:", encoded_df_scaled.min().min())
print("Max value after scaling:", encoded_df_scaled.max().max())
